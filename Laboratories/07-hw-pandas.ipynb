# %% [markdown]
# ## Домашняя работа. Pandas
#
# 1. Скачайте этот ноутбук к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# #### Полезная литература
#
# - http://pandas.pydata.org/pandas-docs/stable/10min.html
# - https://pandas.pydata.org/pandas-docs/stable/indexing.html
# - https://pandas.pydata.org/pandas-docs/stable/missing_data.html

# %% [markdown]
# В этом задании мы с вами рассмотрим датасет [Adult Data Set](https://archive.ics.uci.edu/ml/datasets/Adult).
# Основывается он на данных переписи населения 1994 года в США.
#
# Расшифровка содержимого колонок:
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous. sampling weight, more here: SIPP Weighting.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous. Income from investment sources, apart from wages/salary.
# - capital-loss: continuous. Losses from investment sources, apart from wages/salary.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %%
import pandas as pd
pd.__version__ # 1.4.1
# Out:
# '1.5.3'

# %%
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')
df = pd.read_csv('./adult.csv.gz', na_values='?') # можно загрузить из файла или URL
# df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', na_values='?', names=columns)
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %% [markdown]
# 1) Выведите последние 10 элеметнов датасета

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('adult.csv.gz', na_values='?')

print(df.tail(10))
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 32551   43  Self-emp-not-inc   27242  Some-college             10
# 32552   32           Private   34066          10th              6
# 32553   43           Private   84661     Assoc-voc             11
# 32554   32           Private  116138       Masters             14
# 32555   53           Private  321865       Masters             14
# 32556   22           Private  310152  Some-college             10
# 32557   27           Private  257302    Assoc-acdm             12
# 32558   40           Private  154374       HS-grad              9
# 32559   58           Private  151910       HS-grad              9
# 32560   22           Private  201490       HS-grad              9
#
#            marital.status         occupation   relationship  \
# 32551  Married-civ-spouse       Craft-repair        Husband
# 32552  Married-civ-spouse  Handlers-cleaners        Husband
# ...

# %% [markdown]
# 2) Сколько колонок и сколько строк в этом датасете?

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print ('Столбцов: ', len(df.axes[1]) , '\n', 'Строк: ', len(df.axes[0]))
# Out:
# Столбцов:  15
#  Строк:  32561

# %% [markdown]
# 3) Какие типы данных у элементов этого датасета?

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print (df.dtypes)
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [markdown]
# 4) Какие признаки имеют пропуски?

# %%
import pandas as pd
import numpy as np

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print(df.info()) # общая информация по датафрейму и всем признакам

print(df.describe(include="all")) # статистическая сводка столбцов

#Количество пропусков

for cl in df.columns:
  print(cl, df[cl].isna().sum()) # название, isna(обноруж. NaN)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None
# ...

# %% [markdown]
# 5) Как вы думаете, с чем связаны пропуски этих значение. Напишите развернутый ответ в ячейке ниже.

# %% [markdown]
# 1) Некорректные данные (неправильно ввели, либо просто повреждены);
#
# 2) Некорктные вопросы про рабочее место (workclass);

# %% [markdown]
# 6) Какие и сколько различных рабочих классов workclass представлено в выборке?

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print(df['workclass'].unique()) #список уникальных значений

np.unique(df["workclass"], return_counts=True)

# %% [markdown]
# 7) Какой средний возраст женщин и мужчин?

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print("Средний возраст мужчин и женщин: ", df['age'].mean(), '\n')
print("Средний возраст женщин: ", df[df['sex']== 'Female']['age'].mean() , '\n')
print("Средний возраст мужчин: ",df[df['sex']== 'Male']['age'].mean(), '\n')
# Out:
# Средний возраст мужчин и женщин:  38.58164675532078
#
# Средний возраст женщин:  36.85823043357163
#
# Средний возраст мужчин:  39.43354749885268

# %% [markdown]
# 8) Постройте гистограмму(bar) распределения образования людей (education)

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

(df['education'].hist()).get_figure()

# %% [markdown]
# 9) Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак salary) и тех, кто получает менее 50K в год?

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print("Зарабатывающие >50K: ", df[df['income']== '>50K']['age'].mean() , " и ", df[df['income']== '>50K']['age'].std(),'\n')
print("Зарабатывающие <50K: ", df[df['income']== '<=50K']['age'].mean() , " и ", df[df['income']== '<=50K']['age'].std())
# Out:
# Зарабатывающие >50K:  44.24984058155847  и  10.519027719851826
#
# Зарабатывающие <50K:  36.78373786407767  и  14.020088490824879

# %% [markdown]
# 10) Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education - Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

col = len(df[df['education'] == ('Bachelors' or 'Prof-school' or 'Assoc-acdm' or 'Assoc-voc' or 'Masters' or 'Doctorate')][df['income'] == '>50K'])

print("Имеют как минимум высшее образование и имеют зарплату >50k: ", col)
print("Получается, что таких людей: ", (col/len(df.axes[0]))*100, "% от общего количества равного ", len(df.axes[0]))
# Out:
# Имеют как минимум высшее образование и имеют зарплату >50k:  2221
# Получается, что таких людей:  6.821043579742637 % от общего количества равного  32561
# <ipython-input-14-5c6dd2a5c8e9>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   col = len(df[df['education'] == ('Bachelors' or 'Prof-school' or 'Assoc-acdm' or 'Assoc-voc' or 'Masters' or 'Doctorate')][df['income'] == '>50K'])

# %% [markdown]
# 11) Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status)? Женатыми считаем тех, у кого marital-status начинается с Married (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print("Женатые: ", df[df['marital.status'].str.contains('Married')]['marital.status'][df['income'] == '>50K'].count())
print("Неженатые: ", df[~df['marital.status'].str.contains('Married')]['marital.status'][df['income'] == '>50K'].count())
# Out:
# Женатые:  6736
# Неженатые:  1105

# %% [markdown]
# 12) Посчитайте среднее время работы (hours-per-week) зарабатывающих мало и много (salary) для каждой страны (native-country).

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print(df.groupby(['native.country']).apply(lambda x: x[x['income']== '>50K']['hours.per.week'].mean()),'\n')
print(df.groupby(['native.country']).apply(lambda x: x[x['income']== '<=50K']['hours.per.week'].mean()))
# Out:
# native.country
# Cambodia                      40.000000
# Canada                        45.641026
# China                         38.900000
# Columbia                      50.000000
# Cuba                          42.440000
# Dominican-Republic            47.000000
# Ecuador                       48.750000
# El-Salvador                   45.000000
# England                       44.533333
# France                        50.750000
# Germany                       44.977273
# Greece                        50.625000
# Guatemala                     36.666667
# Haiti                         42.750000
# Holand-Netherlands                  NaN
# Honduras                      60.000000
# Hong                          45.000000
# Hungary                       50.000000
# India                         46.475000
# Iran                          47.500000
# Ireland                       48.000000
# Italy                         45.400000
# Jamaica                       41.100000
# ...

# %% [markdown]
# 13) Постройте сводную таблицу для сравнения уровня образования и разницы между capital.gain и capital.loss (то есть пассивный доход). Сделайте так, чтобы capital.gain - capital.loss создали не больше 10 разных уникальных значений. То есть, gain и loss - это числа в каком-то диапазоне. Это количественные признаки из вещественных чисел. С помощью математических функций, типа log, извлечение корня N-ой степени и округления можно перейти к категориальным признакам.

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

df['capital.diff'] = df['capital.gain'] - df['capital.loss']

df['ones'] = np.ones(df.shape[0])
df['capital.diff'] = df['capital.diff'] - df['capital.diff'].min() + 1
df['capital.diff'] = np.log10(df["capital.diff"])
df['capital.diff'] = np.round(df['capital.diff'])

print(pd.pivot_table(df, index=["education"], columns=["capital.diff"], values=["ones"], aggfunc=[np.sum], fill_value = 0))
# Out:
#               sum
#              ones
# capital.diff  0.0  3.0    4.0 5.0
# education
# 10th            0   27    903   3
# 11th            0   31   1144   0
# 12th            0    8    425   0
# 1st-4th         0    4    164   0
# 5th-6th         0   11    322   0
# 7th-8th         0   22    624   0
# 9th             0    8    505   1
# Assoc-acdm      0   52   1014   1
# Assoc-voc       0   52   1328   2
# Bachelors       0  328   4974  53
# Doctorate       0   53    347  13
# HS-grad         2  385  10085  29
# Masters         0  146   1549  28
# Preschool       0    2     48   1
# Prof-school     0   64    460  52
# Some-college    1  278   6995  17

# %% [markdown]
# 14) Женщины из каких стран получают в среднем большую зарплату (>50K) чаще.

# %%
import pandas as pd
import numpy as np

#Название колонок
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')

#Загрузка csv данных (когда данные запятыми разделены)
df = pd.read_csv('adult.csv.gz', na_values='?')

print(df.groupby(['native.country']).apply(lambda x: ((x[(x['income'] == '<=50K') < (x['income'] == '>50K')]['sex'] == 'Female').count())).sort_values(ascending=False))
# Out:
# native.country
# United-States                 7171
# Philippines                     61
# Germany                         44
# India                           40
# Canada                          39
# Mexico                          33
# England                         30
# Italy                           25
# Cuba                            25
# Japan                           24
# Taiwan                          20
# China                           20
# Iran                            18
# South                           16
# France                          12
# Puerto-Rico                     12
# Poland                          12
# Jamaica                         10
# El-Salvador                      9
# Greece                           8
# Cambodia                         7
# Yugoslavia                       6
# Hong                             6
# Ireland                          5
# Vietnam                          5
# Haiti                            4
# ...
